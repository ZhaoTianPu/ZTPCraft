# %%
import ztpcraft as ztpc
from ztpcraft.toolbox.save import datetime_dir
import numpy as np

# %%
ztpc.tb.units.inductance_2_EL(15E-3)
# Out:
# 10.897434187118746

# %%
ztpc.tb.units.inductance_2_EL(6E-3)
# Out:
# 27.243585467796862

# %%
datetime_dir()
# Out:
# Current datetime directory: ./20240506/12_16/
# './20240506/12_16/'

# %%
from ztpcraft.bosonic.oscillator_integrals import ccosij_complex_GH

# %%
ccosij_complex_GH(0,0,0,0,1,1,1,0)
# Out:
# 0.7788007830714048

# %%
np.linspace(-0.34, -0.5, 161)
# Out:
# array([-0.34 , -0.341, -0.342, -0.343, -0.344, -0.345, -0.346, -0.347,
#        -0.348, -0.349, -0.35 , -0.351, -0.352, -0.353, -0.354, -0.355,
#        -0.356, -0.357, -0.358, -0.359, -0.36 , -0.361, -0.362, -0.363,
#        -0.364, -0.365, -0.366, -0.367, -0.368, -0.369, -0.37 , -0.371,
#        -0.372, -0.373, -0.374, -0.375, -0.376, -0.377, -0.378, -0.379,
#        -0.38 , -0.381, -0.382, -0.383, -0.384, -0.385, -0.386, -0.387,
#        -0.388, -0.389, -0.39 , -0.391, -0.392, -0.393, -0.394, -0.395,
#        -0.396, -0.397, -0.398, -0.399, -0.4  , -0.401, -0.402, -0.403,
#        -0.404, -0.405, -0.406, -0.407, -0.408, -0.409, -0.41 , -0.411,
#        -0.412, -0.413, -0.414, -0.415, -0.416, -0.417, -0.418, -0.419,
#        -0.42 , -0.421, -0.422, -0.423, -0.424, -0.425, -0.426, -0.427,
#        -0.428, -0.429, -0.43 , -0.431, -0.432, -0.433, -0.434, -0.435,
#        -0.436, -0.437, -0.438, -0.439, -0.44 , -0.441, -0.442, -0.443,
# ...

# %%
# Out:
# array([-0.339, -0.338, -0.337, -0.336, -0.335, -0.334, -0.333, -0.332,
#        -0.331, -0.33 , -0.329, -0.328, -0.327, -0.326, -0.325, -0.324,
#        -0.323, -0.322, -0.321, -0.32 , -0.319, -0.318, -0.317, -0.316,
#        -0.315, -0.314, -0.313, -0.312, -0.311, -0.31 , -0.309, -0.308,
#        -0.307, -0.306, -0.305, -0.304, -0.303, -0.302, -0.301, -0.3  ])
